# %%
from palm_roi_ext.instance import AutoRoIExtract
import cv2
import sys
import os
sys.path.append(os.path.abspath(os.path.dirname(os.getcwd())))


roi_ext = AutoRoIExtract(method = 'bezier')


img_path = './data/origin/001_1.JPG'
img = cv2.imread(img_path)


roi_ext.roi_extract_test(img)
# Out:
# 2024-09-24 14:51:28 - my_logger - INFO - 使用设备：cuda:0
